# %% [markdown]
# # Social Media Addiction

# %% [markdown]
# This block imports essential libraries for analyzing student social media data: **pandas** for efficient data manipulation, **numpy** for numerical operations (useful for calculations on usage hours or scores), and **matplotlib.pyplot** for visualizing patterns in student behavior and relationships.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Here, the 'Student Social Media & Relationships' dataset is loaded from 'dataset.csv' into a pandas DataFrame named `df`. This allows us to begin exploring the anonymized records of students' social media behaviors and related life outcomes. The entire DataFrame is then displayed to show the raw data.

# %%
df = pd.read_csv('./dataset.csv')
df
# Out:
#      Student_ID  Age  Gender Academic_Level     Country  \
# 0             1   19  Female  Undergraduate  Bangladesh
# 1             2   22    Male       Graduate       India
# 2             3   20  Female  Undergraduate         USA
# 3             4   18    Male    High School          UK
# 4             5   21    Male       Graduate      Canada
# ..          ...  ...     ...            ...         ...
# 700         701   20  Female  Undergraduate       Italy
# 701         702   23    Male       Graduate      Russia
# 702         703   21  Female  Undergraduate       China
# 703         704   24    Male       Graduate       Japan
# 704         705   19  Female  Undergraduate      Poland
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 0                      5.2          Instagram                          Yes
# 1                      2.1            Twitter                           No
# ...

# %% [markdown]
# This code snippet reveals the **dimensions** of our student social media dataset. It tells us the total number of student responses (rows) and the number of variables (columns) collected, such as `Avg_Daily_Usage_Hours`, `Most_Used_Platform`, and `Addicted_Score`.This code retrieves the dimensions (number of rows and columns) of the DataFrame and stores them in the 'df_shape' variable, which is then displayed.

# %%
df_shape = df.shape
df_shape
# Out:
# (705, 13)

# %% [markdown]
# This line displays the **first 10 student records** from the dataset. It's a quick way to get a feel for the data structure and see a sample of variables like `Age`, `Gender`, `Country`, and their social media usage patterns.

# %%
df.head(10)
# Out:
#    Student_ID  Age  Gender Academic_Level      Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate   Bangladesh                    5.2
# 1           2   22    Male       Graduate        India                    2.1
# 2           3   20  Female  Undergraduate          USA                    6.0
# 3           4   18    Male    High School           UK                    3.0
# 4           5   21    Male       Graduate       Canada                    4.5
# 5           6   19  Female  Undergraduate    Australia                    7.2
# 6           7   23    Male       Graduate      Germany                    1.5
# 7           8   20  Female  Undergraduate       Brazil                    5.8
# 8           9   18    Male    High School        Japan                    4.0
# 9          10   21  Female       Graduate  South Korea                    3.3
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# ...

# %% [markdown]
# This block provides a **summary of the dataset's information**, crucial for understanding the student social media data. It shows the data types for each variable (e.g., `Avg_Daily_Usage_Hours` as float, `Addicted_Score` as integer), identifies any missing values, and indicates memory usage, ensuring data quality for analysis.

# %%
print("Information about the dataset:")
df.info()
# Out:
# Información del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Student_ID                    705 non-null    int64
#  1   Age                           705 non-null    int64
#  2   Gender                        705 non-null    object
#  3   Academic_Level                705 non-null    object
#  4   Country                       705 non-null    object
#  5   Avg_Daily_Usage_Hours         705 non-null    float64
#  6   Most_Used_Platform            705 non-null    object
#  7   Affects_Academic_Performance  705 non-null    object
#  8   Sleep_Hours_Per_Night         705 non-null    float64
#  9   Mental_Health_Score           705 non-null    int64
#  10  Relationship_Status           705 non-null    object
#  11  Conflicts_Over_Social_Media   705 non-null    int64
# ...

# %% [markdown]
# This code generates **descriptive statistics** for the numerical variables in our dataset, such as `Age`, `Avg_Daily_Usage_Hours`, `Sleep_Hours_Per_Night`, `Mental_Health_Score`, and `Addicted_Score`. This gives us a quick overview of the central tendency, dispersion, and shape of these distributions among the surveyed students.

# %%
print("\nDescriptive Statistics:")
df.describe()
# Out:
# Descriptive Statistics:
#        Student_ID         Age  Avg_Daily_Usage_Hours  Sleep_Hours_Per_Night  \
# count  705.000000  705.000000             705.000000             705.000000
# mean   353.000000   20.659574               4.918723               6.868936
# std    203.660256    1.399217               1.257395               1.126848
# min      1.000000   18.000000               1.500000               3.800000
# 25%    177.000000   19.000000               4.100000               6.000000
# 50%    353.000000   21.000000               4.800000               6.900000
# 75%    529.000000   22.000000               5.800000               7.700000
# max    705.000000   24.000000               8.500000               9.600000
#
#        Mental_Health_Score  Conflicts_Over_Social_Media  Addicted_Score
# count           705.000000                   705.000000      705.000000
# mean              6.226950                     2.849645        6.436879
# ...

# %% [markdown]
# This block creates a **histogram** to visualize the distribution of `Avg_Daily_Usage_Hours` among students. It helps us understand how daily social media usage hours are spread across the student population and identify common usage patterns or outliers.

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Avg_Daily_Usage_Hours'], bins=20, edgecolor='black')
plt.title('Distribution of Daily Usage Hours')
plt.xlabel('Hours per day')
plt.ylabel('Frecuency') 
plt.show()

# %% [markdown]
# This code generates a **bar chart** illustrating the most frequently used social media platforms among students, based on the `Most_Used_Platform` variable. This visualization helps us identify which platforms are dominant within the surveyed student population.

# %%
platform_counts = df['Most_Used_Platform'].value_counts()
plt.figure(figsize=(12, 6))
platform_counts.plot(kind='bar')
plt.title('Most Used Platforms')
plt.xlabel('Platform')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# This block creates a **scatter plot** to explore the relationship between students' `Avg_Daily_Usage_Hours` and their `Addicted_Score`. It visually indicates if there's a trend, and then calculates and prints the **Pearson correlation coefficient** to quantify the strength and direction of this relationship, helping us understand the link between usage and addiction.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Avg_Daily_Usage_Hours'], df['Addicted_Score'], alpha=0.5)
plt.title('Relationship between Average Daily Usage Hours and Addicted Score')
plt.xlabel('Average Daily Usage Hours')
plt.ylabel('Addicted Score')
plt.show()

# Correlación
correlation = df['Avg_Daily_Usage_Hours'].corr(df['Addicted_Score'])
print(f'The correlation between the average daily usage hours and the addicted score is: {correlation:.2f}')
# Out:
# The correlation between the average daily usage hours and the addicted score is: 0.83
